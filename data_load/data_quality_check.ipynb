# %%
# Importing libraries
import pandas as pd
import numpy as np

# Read csv file into a pandas dataframe
# We choose `WikiArt-Emotions-Ag4.tsv` because it is an aggregation of emotions where at least 40% of the annotators agreed on the emotion. 
# This aggregated dataset is recommended by the dataset creator http://saifmohammad.com/WebPages/wikiartemotions.html
df = pd.read_csv("WikiArt-Emotions-Ag4.tsv", sep='\t', header=0)

# %%
# Preview Contents
df.head()
# Out:
#                          ID                 Style            Category  \
# 0  58c6237dedc2c9c7dc0de1ae            Modern Art       Impressionism
# 1  577280dfedc2cb3880f28e76            Modern Art   Neo-Expressionism
# 2  57727f2dedc2cb3880ed5fa9            Modern Art  Post-Impressionism
# 3  58d1240cedc2c94f900fc610            Modern Art              Cubism
# 4  57727de7edc2cb3880e91f26  Post Renaissance Art         Romanticism
#
#                     Artist                                          Title  \
# 0  Charles Courtney Curran                       In the Luxembourg Garden
# 1             Keith Haring                The Marriage of Heaven and Hell
# 2       Jozsef Rippl-Ronai  Uncle Piacsek in front of the Black Sideboard
# 3             Vadym Meller           Monk. For the Play &#39;Mazeppa&#39;
# 4             David Wilkie                   The Defence of Sarago&#231;a
#
#    Year                                          Image URL  \
# ...

# %%
# Check for any null values
df.isnull().sum()
# Out:
# ID                     0
# Style                  0
# Category               0
# Artist                 0
# Title                  0
#                       ..
# TitleOnly: shame       0
# TitleOnly: shyness     0
# TitleOnly: surprise    0
# TitleOnly: trust       0
# TitleOnly: neutral     0
# Length: 72, dtype: int64
